# %%
# prompt: write code to read csv file into a df

import pandas as pd

# Install pandas if not already installed
# !pip install pandas

file_path = '/content/Ground Water 2021.csv' # Replace with your CSV file path
try:
  dfmain = pd.read_csv(file_path)
  print(df.head()) # Print the first few rows of the DataFrame
except FileNotFoundError:
  print(f"Error: File '{file_path}' not found.")
except pd.errors.EmptyDataError:
  print(f"Error: File '{file_path}' is empty.")
except pd.errors.ParserError:
  print(f"Error: Unable to parse the CSV file '{file_path}'. Check the file format.")
except Exception as e:
  print(f"An unexpected error occurred: {e}")
# Out:
# ...
#    Station Code                                       Station Name  \
# 0        3093.0  BORE WELL AT ALLADAPALEM\nVILLAGE, PYDIBHIMAVARAM
# 1        3092.0       BORE WELL AT ARINAMA\nAKKIVALASA, SRIKAKULAM
# 2        4360.0         BORE WELL AT IDA,\nRAMANAYYAPETA, KKAINADA
# 3        3091.0  BORE WELL AT KAPULUPPADA\nDUMPSITE, VISHAKHAPA...
# 4        4353.0  BORE WELL AT MANGARAJU\nHOUSE, GAJAPATHINAGARA...
#
#             STATE  Temperature Min  Temperature Max  pH Min  pH Max  \
# 0  ANDHRA PRADESH             29.0             30.0     7.3     7.4
# 1  ANDHRA PRADESH             28.0             31.0     7.4     8.1
# 2  ANDHRA PRADESH             27.0             29.0     7.7     7.8
# 3  ANDHRA PRADESH             26.0             26.0     7.0     7.1
# 4  ANDHRA PRADESH             25.0             27.0     7.9     8.1
#
#    Conductivity (µmhos/cm) Min  Conductivity (µmhos/cm) Max  Year
# 0                        840.0                       1481.0  2021
# ...

# %%
dfmain.head()
# Out:
#    Station Code                                       Station Name  \
# 0        3093.0  BORE WELL AT ALLADAPALEM\nVILLAGE, PYDIBHIMAVARAM
# 1        3092.0       BORE WELL AT ARINAMA\nAKKIVALASA, SRIKAKULAM
# 2        4360.0         BORE WELL AT IDA,\nRAMANAYYAPETA, KKAINADA
# 3        3091.0  BORE WELL AT KAPULUPPADA\nDUMPSITE, VISHAKHAPA...
# 4        4353.0  BORE WELL AT MANGARAJU\nHOUSE, GAJAPATHINAGARA...
#
#             STATE  Temperature Min  Temperature Max  pH Min  pH Max  \
# 0  ANDHRA PRADESH             29.0             30.0     7.3     7.4
# 1  ANDHRA PRADESH             28.0             31.0     7.4     8.1
# 2  ANDHRA PRADESH             27.0             29.0     7.7     7.8
# 3  ANDHRA PRADESH             26.0             26.0     7.0     7.1
# 4  ANDHRA PRADESH             25.0             27.0     7.9     8.1
#
#    Conductivity (µmhos/cm) Min  Conductivity (µmhos/cm) Max  Year
# 0                        840.0                       1481.0  2021
# ...

# %%
dfaux=pd.read_csv('/content/hardwork.csv')

# %%
dfaux.head()
# Out:
#    Water\nQuality Station Code  \
# 0                           14
# 1                           25
# 2                           26
# 3                           30
# 4                         1174
#
#               Name or Location of Monitoring Station        State/UT  \
# 0      GODAVARI AT POLAVARAM, WEST GODAVARI DISTRICT  ANDHRA PRADESH
# 1                      KRISHNA AT VIJAYWADA, KRISHNA  ANDHRA PRADESH
# 2  WELL AT GRAM PANCHAYAT OFFICE, KAANURU, VIJAYWADA  ANDHRA PRADESH
# 3                        PENNAR AT SIDDVATAM, KADAPA  ANDHRA PRADESH
# 4    TUNGABHADRA AT KURNOOL U/S, BHAVAPURAM, KURNOOL  ANDHRA PRADESH
#
#   Type of Water Body Frequency of Monitoring   Latitude  Longitude
# 0              RIVER                 MONTHLY  17.247331  81.646613
# 1              RIVER                 MONTHLY  16.492476  80.640839
# 2       GROUND WATER             HALF-YEARLY  16.508853  80.641519
# 3              RIVER                 MONTHLY  14.464393  78.964627
# ...

# %%
dfaux.shape
# Out:
# (4111, 7)

# %%
dfaux.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4111 entries, 0 to 4110
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   Water
# Quality Station Code              4111 non-null   int64
#  1   Name or Location of Monitoring Station  4111 non-null   object
#  2   State/UT                                4111 non-null   object
#  3   Type of Water Body                      4111 non-null   object
#  4   Frequency of Monitoring                 4111 non-null   object
#  5   Latitude                                4111 non-null   float64
#  6   Longitude                               4111 non-null   float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 224.9+ KB

# %%
# prompt: in dfaux remove all the rows which doent contain ground water as the type of water body

dfaux = dfaux[dfaux['Type of Water Body'] == 'GROUND WATER']

# %%
dfaux.shape
# Out:
# (1233, 7)

# %%
dfaux
# Out:
#       Water\nQuality Station Code  \
# 2                              26
# 14                           1513
# 15                           1514
# 16                           1516
# 17                           1517
# ...                           ...
# 4095                         4733
# 4096                         4734
# 4097                         4735
# 4098                         4736
# 4099                         4737
#
#                  Name or Location of Monitoring Station        State/UT  \
# 2     WELL AT GRAM PANCHAYAT OFFICE, KAANURU, VIJAYWADA  ANDHRA PRADESH
# 14    BOREWELL KRISHNA MURTHY, D.NO. 48-16-43 AUTONA...  ANDHRA PRADESH
# 15            BOREWELL VIJAY KUMAR AUTONAGAR VIJAYAWADA  ANDHRA PRADESH
# 16                  BOREWELL OF NAVLOK GARDENS, NELLORE  ANDHRA PRADESH
# 17               BOREWELL NEAR TUNGBHADRA RIVER KURNOOL  ANDHRA PRADESH
# ...                                                 ...             ...
# ...

# %%
# prompt: remove all the columns except staion code, latitude and longitude

import pandas as pd

# Assuming dfaux is your DataFrame
# Replace with your actual DataFrame name if different

columns_to_keep = ['Water\nQuality Station Code', 'Latitude', 'Longitude']
dfaux = dfaux[columns_to_keep]

dfaux.head()
# Out:
#     Water\nQuality Station Code   Latitude  Longitude
# 2                            26  16.508853  80.641519
# 14                         1513  16.501486  80.675692
# 15                         1514  16.501508  80.676725
# 16                         1516  14.445036  79.987869
# 17                         1517  15.836300  78.048593

# %%
# prompt: download this dfaux in excel format

from google.colab import files
dfaux.to_excel('dfaux.xlsx', index=False)
files.download('dfaux.xlsx')

# %%
df.head()
# Out:
#    Station Code                                       Station Name  \
# 0        3093.0  BORE WELL AT ALLADAPALEM\nVILLAGE, PYDIBHIMAVARAM
# 1        3092.0       BORE WELL AT ARINAMA\nAKKIVALASA, SRIKAKULAM
# 2        4360.0         BORE WELL AT IDA,\nRAMANAYYAPETA, KKAINADA
# 3        3091.0  BORE WELL AT KAPULUPPADA\nDUMPSITE, VISHAKHAPA...
# 4        4353.0  BORE WELL AT MANGARAJU\nHOUSE, GAJAPATHINAGARA...
#
#             STATE  Temperature Min  Temperature Max  pH Min  pH Max  \
# 0  ANDHRA PRADESH             29.0             30.0     7.3     7.4
# 1  ANDHRA PRADESH             28.0             31.0     7.4     8.1
# 2  ANDHRA PRADESH             27.0             29.0     7.7     7.8
# 3  ANDHRA PRADESH             26.0             26.0     7.0     7.1
# 4  ANDHRA PRADESH             25.0             27.0     7.9     8.1
#
#    Conductivity (µmhos/cm) Min  Conductivity (µmhos/cm) Max  Year
# 0                        840.0                       1481.0  2021
# ...

# %%
# prompt: from this df perform mean for temperature min and temperature max and add this info to a new column replacing both of the columns

# Calculate the mean of 'Temperature Min' and 'Temperature Max'
df['Temperature Mean'] = df[['Temperature Min', 'Temperature Max']].mean(axis=1)

# Drop the original 'Temperature Min' and 'Temperature Max' columns
df = df.drop(['Temperature Min', 'Temperature Max'], axis=1)

# Display the updated DataFrame
df.head()
# Out:
#    Station Code                                       Station Name  \
# 0        3093.0  BORE WELL AT ALLADAPALEM\nVILLAGE, PYDIBHIMAVARAM
# 1        3092.0       BORE WELL AT ARINAMA\nAKKIVALASA, SRIKAKULAM
# 2        4360.0         BORE WELL AT IDA,\nRAMANAYYAPETA, KKAINADA
# 3        3091.0  BORE WELL AT KAPULUPPADA\nDUMPSITE, VISHAKHAPA...
# 4        4353.0  BORE WELL AT MANGARAJU\nHOUSE, GAJAPATHINAGARA...
#
#             STATE  pH Min  pH Max  Conductivity (µmhos/cm) Min  \
# 0  ANDHRA PRADESH     7.3     7.4                        840.0
# 1  ANDHRA PRADESH     7.4     8.1                        712.0
# 2  ANDHRA PRADESH     7.7     7.8                        990.0
# 3  ANDHRA PRADESH     7.0     7.1                       3340.0
# 4  ANDHRA PRADESH     7.9     8.1                       2660.0
#
#    Conductivity (µmhos/cm) Max  Year  Temperature Mean
# 0                       1481.0  2021              29.5
# 1                       1139.0  2021              29.5
# ...

# %%
# prompt: from this df perform mean for temperature min and temperature max and add this info to a new column replacing both of the columns

# Calculate the mean of 'Temperature Min' and 'Temperature Max'
df['pH mean'] = df[['pH Min', 'pH Max']].mean(axis=1)

# Drop the original 'Temperature Min' and 'Temperature Max' columns
df = df.drop(['pH Min', 'pH Max'], axis=1)

# Display the updated DataFrame
df.head()
# Out:
#    Station Code                                       Station Name  \
# 0        3093.0  BORE WELL AT ALLADAPALEM\nVILLAGE, PYDIBHIMAVARAM
# 1        3092.0       BORE WELL AT ARINAMA\nAKKIVALASA, SRIKAKULAM
# 2        4360.0         BORE WELL AT IDA,\nRAMANAYYAPETA, KKAINADA
# 3        3091.0  BORE WELL AT KAPULUPPADA\nDUMPSITE, VISHAKHAPA...
# 4        4353.0  BORE WELL AT MANGARAJU\nHOUSE, GAJAPATHINAGARA...
#
#             STATE  Conductivity (µmhos/cm) Min  Conductivity (µmhos/cm) Max  \
# 0  ANDHRA PRADESH                        840.0                       1481.0
# 1  ANDHRA PRADESH                        712.0                       1139.0
# 2  ANDHRA PRADESH                        990.0                       1280.0
# 3  ANDHRA PRADESH                       3340.0                       4260.0
# 4  ANDHRA PRADESH                       2660.0                       3940.0
#
#    Year  Temperature Mean  pH mean
# 0  2021              29.5     7.35
# ...

# %%
# prompt: from this df perform mean for temperature min and temperature max and add this info to a new column replacing both of the columns

# Calculate the mean of 'Temperature Min' and 'Temperature Max'
df['Conductivity (µmhos/cm) Mean'] = df[['Conductivity (µmhos/cm) Min', 'Conductivity (µmhos/cm) Max']].mean(axis=1)

# Drop the original 'Temperature Min' and 'Temperature Max' columns
df = df.drop(['Conductivity (µmhos/cm) Min', 'Conductivity (µmhos/cm) Max'], axis=1)

# Display the updated DataFrame
df.head()
# Out:
#    Station Code                                       Station Name  \
# 0        3093.0  BORE WELL AT ALLADAPALEM\nVILLAGE, PYDIBHIMAVARAM
# 1        3092.0       BORE WELL AT ARINAMA\nAKKIVALASA, SRIKAKULAM
# 2        4360.0         BORE WELL AT IDA,\nRAMANAYYAPETA, KKAINADA
# 3        3091.0  BORE WELL AT KAPULUPPADA\nDUMPSITE, VISHAKHAPA...
# 4        4353.0  BORE WELL AT MANGARAJU\nHOUSE, GAJAPATHINAGARA...
#
#             STATE  Year  Temperature Mean  pH mean  \
# 0  ANDHRA PRADESH  2021              29.5     7.35
# 1  ANDHRA PRADESH  2021              29.5     7.75
# 2  ANDHRA PRADESH  2021              28.0     7.75
# 3  ANDHRA PRADESH  2021              26.0     7.05
# 4  ANDHRA PRADESH  2021              26.0     8.00
#
#    Conductivity (µmhos/cm) Mean
# 0                        1160.5
# 1                         925.5
# 2                        1135.0
# 3                        3800.0
# 4                        3300.0

# %%
# prompt: drop station name,state, year columns

# Assuming 'df' is your DataFrame
# Replace 'df' with the actual name of your DataFrame if different

# Drop columns by name
df = df.drop(['Station Name', 'STATE', 'Year'], axis=1, errors='ignore')

# Display the updated DataFrame
df.head()
# Out:
#    Station Code  Temperature Mean  pH mean  Conductivity (µmhos/cm) Mean
# 0        3093.0              29.5     7.35                        1160.5
# 1        3092.0              29.5     7.75                         925.5
# 2        4360.0              28.0     7.75                        1135.0
# 3        3091.0              26.0     7.05                        3800.0
# 4        4353.0              26.0     8.00                        3300.0

# %%
df.shape
# Out:
# (988, 4)

# %%
# prompt: download this df

df.to_excel('dfprimary.xlsx', index=False)
files.download('dfprimary.xlsx')

# %%
# prompt: now you have to match the station code in dfaux and df dataframes and add the latitude and longitude info to the df

import pandas as pd
# Merge the dataframes based on the common column 'Water\nQuality Station Code'
dfbeta = pd.merge(df, dfaux, left_on='Station Code', right_on='Water\nQuality Station Code', how='left')

# Drop the redundant 'Water\nQuality Station Code' column
dfbeta = dfbeta.drop('Water\nQuality Station Code', axis=1)

# Display the updated DataFrame
dfbeta.head()
# Out:
#    Station Code  Temperature Mean  pH mean  Conductivity (µmhos/cm) Mean  \
# 0        3093.0              29.5     7.35                        1160.5
# 1        3092.0              29.5     7.75                         925.5
# 2        4360.0              28.0     7.75                        1135.0
# 3        3091.0              26.0     7.05                        3800.0
# 4        4353.0              26.0     8.00                        3300.0
#
#     Latitude  Longitude
# 0  18.135208  83.613470
# 1  18.576520  84.015135
# 2  16.986264  82.234925
# 3  17.845289  83.368911
# 4  18.279708  83.333591

# %%
dfbeta.shape
# Out:
# (988, 6)

# %%
# prompt: download this dfbeta as excel

dfbeta.to_excel('maindatasetforembedded.xlsx', index=False)
files.download('maindatasetforembedded.xlsx')
